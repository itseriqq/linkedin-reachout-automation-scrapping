# %% [markdown]
# <a href="https://colab.research.google.com/github/itseriqq/linkedin-reachout-automation-scrapping/blob/main/linkedin_profiles_reachout_automationl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import gspread
from google.oauth2.service_account import Credentials
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
from googleapiclient.errors import HttpError
from pydantic import BaseModel
import os
from typing import List, Dict
from google import genai
import time
import requests

from google.colab import userdata

# Configurações
BRIGHT_DATA_API_KEY = userdata.get('brightDataKey')
BRIGHT_DATA_API_URL = 'https://api.brightdata.com/scrape/linkedin'
GOOGLE_SHEETS_CREDENTIALS_FILE = 'credentials.json'
SPREADSHEET_ID = '1XgLaKmZpfcr5GMw1qDfSJw5rJVeE-a-KR4ReNixUW1o'
CURRICULO_PATH = '/content/curriculo_erick.pdf'
client = genai.Client(api_key=userdata.get('keyGemini'))

# %%
# Função para salvar dados em JSON
def salvar_json(dados: List[Dict], caminho_arquivo: str):
    with open(caminho_arquivo, 'w', encoding='utf-8') as f:
        json.dump(dados, f, ensure_ascii=False, indent=4)
    print(f'Dados salvos em {caminho_arquivo}')

# Função para carregar dados do JSON
def carregar_json(caminho_arquivo: str) -> List[Dict]:
    try:
        with open(caminho_arquivo, 'r', encoding='utf-8') as f:
            return json.load(f)
    except FileNotFoundError:
        print(f'Arquivo {caminho_arquivo} não encontrado.')
        return []

# %%
import pathlib
from google.genai import types

def extrair_curriculo_gemini(path: str):
    TXT_PATH = "/content/curriculo.json"
    if pathlib.Path(TXT_PATH).exists():
        print("Carregando currículo do arquivo salvo.")
        with open(TXT_PATH, 'r', encoding='utf-8') as f:
            return json.load(f)

    print("Processando PDF com Gemini...")
    filepath = pathlib.Path(path)

    if not filepath.exists():
        print(f"Erro: Arquivo {path} não encontrado.")
        return {}

    print(f"Lendo PDF: {filepath}")
    with open(filepath, 'rb') as f:
        pdf_data = f.read()

    prompt = """
    Analise este currículo e retorne APENAS um objeto JSON válido (sem marcadores de código, sem texto adicional) com os seguintes campos:
    {
        "firstName": "string",
        "lastName": "string",
        "location": "string",
        "emailAddress": "string",
        "telephoneNumber": "string",
        "introduction": "string",
        "experience": [
            {
                "company": "string",
                "jobTitle": "string",
                "description": "string"
            }
        ],
        "skills": ["string"]
    }
    """

    try:
        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=[
                types.Part.from_bytes(
                    data=pdf_data,
                    mime_type='application/pdf',
                ),
                prompt
            ]
        )

        print("Resposta do Gemini recebida.")
        print("Texto da resposta:", response.text)

        if response.text:
            texto_limpo = response.text.strip()
            if texto_limpo.startswith("```json"):
                texto_limpo = texto_limpo[7:]
            if texto_limpo.startswith("```"):
                texto_limpo = texto_limpo[3:]
            if texto_limpo.endswith("```"):
                texto_limpo = texto_limpo[:-3]
            texto_limpo = texto_limpo.strip()

            print("Texto limpo:", texto_limpo)

            # Converte para dicionário
            curriculo_dict = json.loads(texto_limpo)

            # Salva o JSON
            with open(TXT_PATH, 'w', encoding='utf-8') as f:
                json.dump(curriculo_dict, f, ensure_ascii=False, indent=4)
            print(f"Currículo salvo em {TXT_PATH}")

            return curriculo_dict
        else:
            print("Erro: Resposta vazia do Gemini.")
            return {}

    except json.JSONDecodeError as e:
        print(f"Erro ao parsear JSON: {e}")
        print(f"Texto recebido: {response.text}")
        return {}
    except Exception as e:
        print(f"Erro ao processar currículo: {e}")
        return {}

# %%
def gerar_mensagem_gemini(nome: str, empresa: str, cargo: str, curriculo: Dict) -> str:
    print(f"\n=== Gerando mensagem para {nome} ===")

    firstName = curriculo.get("firstName", "Nome")
    lastName = curriculo.get("lastName", "Sobrenome")
    introduction = curriculo.get("introduction", "")

    experiencias = curriculo.get('experience', [])
    if experiencias:
        experiencia = ' '.join([exp.get('description', '') for exp in experiencias if exp.get('description')])
    else:
        experiencia = "Desenvolvedor de software com experiência em projetos diversos"

    skills_list = curriculo.get('skills', [])
    if skills_list:
        skills = ', '.join(skills_list)
    else:
        skills = "desenvolvimento de software"

    print(f"Nome completo: {firstName} {lastName}")
    print(f"Skills: {skills[:100]}...")

    prompt = f"""
    Escreva uma mensagem de outreach personalizada para {nome}, que trabalha na {empresa} como {cargo}.
    Minha experiência: {experiencia}
    Minhas habilidades: {skills}
    Quero saber se há oportunidades de colaboração ou indicação de vagas relevantes.
    Seja profissional e direto, mas não soe como spam e, como esperamos vagas em inglês, preciso que seja em inglês a mensagem, de forma direta e cordial.

    A mensagem deve seguir a estrutura:

    Dear {nome},

    I hope this message finds you well.

    My name is {firstName} {lastName}, and I'm a Software Engineer with experience in building full-stack applications and developing solutions. I came across your profile on LinkedIn and was particularly interested in getting a job to work with you at {empresa}, if there's any chance or role available.

    Given {empresa}'s work, I'm especially interested in exploring how my skills in {skills} might align with projects and opportunities within your teams. Although I have this tech formation and knowledge I'm really interested in working with you.

    I'm reaching out to you as an experienced professional at {empresa} to inquire if there might be any opportunities for collaboration, or if you would be open to providing an indication of relevant open positions where my background could be a good fit.

    I would be happy to share my CV or portfolio for your review. Would you be open to a brief 15-minute chat sometime this week to discuss this further?

    Thank you for your time and consideration.

    Best regards,
    {firstName} {lastName}

    Coloque a mensagem gerada entre as tags <texto> e </texto>.
    """

    print("Enviando prompt para Gemini...")
    try:
        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=prompt
        )

        print("Resposta recebida do Gemini.")
        print("Texto completo da resposta:")
        print(response.text[:500] + "..." if len(response.text) > 500 else response.text)

        if "<texto>" in response.text and "</texto>" in response.text:
            start = response.text.find("<texto>") + len("<texto>")
            end = response.text.find("</texto>")
            mensagem = response.text[start:end].strip()
            print("✓ Mensagem extraída com sucesso")
            return mensagem
        else:
            print("⚠ Tags <texto> não encontradas. Retornando resposta completa.")
            return response.text.strip()

    except Exception as e:
        print(f"✗ Erro ao chamar Gemini: {e}")
        import traceback
        traceback.print_exc()
        return f"Erro ao gerar mensagem: {str(e)}"

# %%
from typing import Dict

def gerar_mensagem_template(nome: str, empresa: str, cargo: str, curriculo: Dict) -> str:
    print(f"\n=== Gerando mensagem para {nome} ===")

    firstName = curriculo.get("firstName", "Nome")
    lastName = curriculo.get("lastName", "Sobrenome")

    experiencias = curriculo.get('experience', [])
    if experiencias:
        experiencia = ' '.join(
            exp.get('description', '')
            for exp in experiencias
            if exp.get('description')
        )
    else:
        experiencia = "Desenvolvedor de software com experiência em projetos diversos"

    skills_list = curriculo.get('skills', [])
    if skills_list:
        skills = ', '.join(skills_list)
    else:
        skills = "desenvolvimento de software"

    print(f"Nome completo: {firstName} {lastName}")
    print(f"Skills: {skills[:100]}...")

    mensagem = f"""Dear {nome},

      I hope this message finds you well.

      My name is {firstName} {lastName}, and I'm a Software Engineer with experience in building full-stack applications and developing solutions. I came across your profile on LinkedIn and was particularly interested in getting a job to work with you at {empresa}, if there's any chance or role available.

      Given {empresa}'s work, I'm especially interested in exploring how my skills in {skills} might align with projects and opportunities within your teams. Although I have this tech formation and knowledge I'm really interested in working with you.

      I'm reaching out to you as an experienced professional at {empresa} to inquire if there might be any opportunities for collaboration, or if you would be open to providing an indication of relevant open positions where my background could be a good fit.

      I would be happy to share my CV or portfolio for your review. Would you be open to a brief 15-minute chat sometime this week to discuss this further?

      Thank you for your time and consideration.

      Best regards,
      {firstName} {lastName}
      """

    return mensagem

# %%
import requests
DATASET_ID = "gd_mfz5x93lmsjjjylob"

trigger_url = f"https://api.brightdata.com/datasets/v3/trigger?dataset_id={DATASET_ID}&include_errors=true"
trigger_response = requests.post(
    trigger_url,
    headers={
        "Content-Type": "application/json",
        "Authorization": f"Bearer {BRIGHT_DATA_API_KEY}",
    },
    json=[
            {
              "url": "https://www.google.com/",
              "keyword": 'site:linkedin.com/in ("Software Engineer" OR "Technical Recruiter" OR "Talent Acquisition" OR "TypeScript/JavaScript" OR "React.js" OR "Next.js")',
              "language": "en",
              "country": "US",
              "start_page": 1,
              "end_page": 10,
            }
    ],
)

snapshot_id = trigger_response.json()["snapshot_id"]

progress = None
while progress is None or progress["status"] != "ready":
    time.sleep(5)  # Wait 5 seconds
    progress_url = f"https://api.brightdata.com/datasets/v3/progress/{snapshot_id}"
    progress_response = requests.get(
        progress_url,
        headers={"Authorization": f"Bearer {BRIGHT_DATA_API_KEY}"},
    )
    progress = progress_response.json()

# Step 3: Download results
download_url = f"https://api.brightdata.com/datasets/v3/snapshot/{snapshot_id}?format=json"
download_response = requests.get(
    download_url,
    headers={"Authorization": f"Bearer {BRIGHT_DATA_API_KEY}"},
)

results = download_response.json()
print(results)
# Out:
# [{'url': 'https://www.google.com/', 'keyword': 'site:linkedin.com/in ("Software Engineer" OR "Technical Recruiter" OR "Talent Acquisition" OR "TypeScript/JavaScript" OR "React.js" OR "Next.js")', 'general': {'search_engine': 'google', 'language': 'en', 'location': 'Trinity, Florida', 'search_type': 'text', 'page_title': 'site:linkedin.com/in ("Software Engineer" OR "Technical Recruiter" OR "Talent Acquisition" OR "TypeScript/JavaScript" OR "React.js" OR "Next.js") - Google Search', 'datetime': '2025-12-09T03:42:10.141Z', 'query': 'site:linkedin.com/in ("Software Engineer" OR "Technical Recruiter" OR "Talent Acquisition" OR "TypeScript/JavaScript" OR "React.js" OR "Next.js")'}, 'related': [], 'pagination': [{'page': '2', 'link': 'https://www.google.com/search?q=site:linkedin.com/in+(%22Software+Engineer%22+OR+%22Technical+Recruiter%22+OR+%22Talent+Acquisition%22+OR+%22TypeScript/JavaScript%22+OR+%22React.js%22+OR+%22Next.js%22)&sca_esv=ad1c47de9cd56ce0&gl=US&hl=en&ei=iJo3aengIqqLwbkPtpi34Q4&start=10&sa=N&sstk=Af77f_ep_Bh3ip_i-EZFrRHhxgZLos7CU9RJfbE8Wffc7X6-oBCiiCxwDw0nRIssM8YgoTGwgXCa2i6_E27KbpxG22j7TPLHEbJpfw&ved=2ahUKEwjpxPmNy6-RAxWqRTABHTbMLewQ8tMDegQIDBAE&num=10', 'page_html': None}, {'page': '3', 'link': 'https://www.google.com/search?q=site:linkedin.com/in+(%22Software+Engineer%22+OR+%22Technical+Recruiter%22+OR+%22Talent+Acquisition%22+OR+%22TypeScript/JavaScript%22+OR+%22React.js%22+OR+%22Next.js%22)&sca_esv=ad1c47de9cd56ce0&gl=US&hl=en&ei=iJo3aengIqqLwbkPtpi34Q4&start=20&sa=N&sstk=Af77f_ep_Bh3ip_i-EZFrRHhxgZLos7CU9RJfbE8Wffc7X6-oBCiiCxwDw0nRIssM8YgoTGwgXCa2i6_E27KbpxG22j7TPLHEbJpfw&ved=2ahUKEwjpxPmNy6-RAxWqRTABHTbMLewQ8tMDegQIDBAG&num=10', 'page_html': None}, {'page': '4', 'link': 'https://www.google.com/search?q=site:linkedin.com/in+(%22Software+Engineer%22+OR+%22Technical+Recruiter%22+OR+%22Talent+Acquisition%22+OR+%22TypeScript/JavaScript%22+OR+%22React.js%22+OR+%22Next.js%22)&sca_esv=ad1c47de9cd56ce0&gl=US&hl=en&ei=iJo3aengIqqLwbkPtpi34Q4&start=30&sa=N&sstk=Af77f_ep_Bh3ip_i-EZFrRHhxgZLos7CU9RJfbE8Wffc7X6-oBCiiCxwDw0nRIssM8YgoTGwgXCa2i6_E27KbpxG22j7TPLHEbJpfw&ved=2ahUKEwjpxPmNy6-RAxWqRTABHTbMLewQ8tMDegQIDBAI&num=10', 'page_html': None}, {'page': '5', 'link': 'https://www.google.com/search?q=site:linkedin.com/in+(%22Software+Engineer%22+OR+%22Technical+Recruiter%22+OR+%22Talent+Acquisition%22+OR+%22TypeScript/JavaScript%22+OR+%22React.js%22+OR+%22Next.js%22)&sca_esv=ad1c47de9cd56ce0&gl=US&hl=en&ei=iJo3aengIqqLwbkPtpi34Q4&start=40&sa=N&sstk=Af77f_ep_Bh3ip_i-EZFrRHhxgZLos7CU9RJfbE8Wffc7X6-oBCiiCxwDw0nRIssM8YgoTGwgXCa2i6_E27KbpxG22j7TPLHEbJpfw&ved=2ahUKEwjpxPmNy6-RAxWqRTABHTbMLewQ8tMDegQIDBAK&num=10', 'page_html': None}, {'page': '6', 'link': 'https://www.google.com/search?q=site:linkedin.com/in+(%22Software+Engineer%22+OR+%22Technical+Recruiter%22+OR+%22Talent+Acquisition%22+OR+%22TypeScript/JavaScript%22+OR+%22React.js%22+OR+%22Next.js%22)&sca_esv=ad1c47de9cd56ce0&gl=US&hl=en&ei=iJo3aengIqqLwbkPtpi34Q4&start=50&sa=N&sstk=Af77f_ep_Bh3ip_i-EZFrRHhxgZLos7CU9RJfbE8Wffc7X6-oBCiiCxwDw0nRIssM8YgoTGwgXCa2i6_E27KbpxG22j7TPLHEbJpfw&ved=2ahUKEwjpxPmNy6-RAxWqRTABHTbMLewQ8tMDegQIDBAM&num=10', 'page_html': None}, {'page': '7', 'link': 'https://www.google.com/search?q=site:linkedin.com/in+(%22Software+Engineer%22+OR+%22Technical+Recruiter%22+OR+%22Talent+Acquisition%22+OR+%22TypeScript/JavaScript%22+OR+%22React.js%22+OR+%22Next.js%22)&sca_esv=ad1c47de9cd56ce0&gl=US&hl=en&ei=iJo3aengIqqLwbkPtpi34Q4&start=60&sa=N&sstk=Af77f_ep_Bh3ip_i-EZFrRHhxgZLos7CU9RJfbE8Wffc7X6-oBCiiCxwDw0nRIssM8YgoTGwgXCa2i6_E27KbpxG22j7TPLHEbJpfw&ved=2ahUKEwjpxPmNy6-RAxWqRTABHTbMLewQ8tMDegQIDBAO&num=10', 'page_html': None}, {'page': '8', 'link': 'https://www.google.com/search?q=site:linkedin.com/in+(%22Software+Engineer%22+OR+%22Technical+Recruiter%22+OR+%22Talent+Acquisition%22+OR+%22TypeScript/JavaScript%22+OR+%22React.js%22+OR+%22Next.js%22)&sca_esv=ad1c47de9cd56ce0&gl=US&hl=en&ei=iJo3aengIqqLwbkPtpi34Q4&start=70&sa=N&sstk=Af77f_ep_Bh3ip_i-EZFrRHhxgZLos7CU9RJ ...

# %%
def extrair_perfis_linkedin(resultados):
    perfis = []

    for item in resultados:
        organic = item.get("organic", [])
        for r in organic:
            link = r.get("link", "")
            if "linkedin.com/in/" in link:
                perfis.append({
                    "profile_url": link,
                    "title": r.get("title", ""),
                    "snippet": r.get("snippet", "")
                })

    return perfis

# %%
def parse_nome_cargo_empresa(title: str):
    nome = ""
    cargo = ""
    empresa = ""

    if " - " in title:
        nome, resto = title.split(" - ", 1)

        if " at " in resto:
            cargo, empresa = resto.split(" at ", 1)
        else:
            cargo = resto
    else:
        nome = title

    return nome.strip(), cargo.strip(), empresa.strip()

def normalizar_perfis(perfis_raw):
    saida = []

    for p in perfis_raw:
        title = p.get("title", "")
        link = p.get("link") or p.get("profile_url", "")

        nome, cargo, empresa = parse_nome_cargo_empresa(title)

        # fallback de segurança
        if not nome:
            continue

        saida.append({
            "nome": nome,
            "cargo": cargo or "Professional",
            "empresa": empresa or "the company",
            "link": link
        })

    return saida

# %%
def salvar_no_sheets(dados: List[Dict], spreadsheet_id: str, sheet_name: str = 'Página1'):
    scopes = ['https://www.googleapis.com/auth/spreadsheets']
    credentials = Credentials.from_service_account_file(
        GOOGLE_SHEETS_CREDENTIALS_FILE,
        scopes=scopes
    )
    service = build('sheets', 'v4', credentials=credentials)

    # apenas os dados, sem cabeçalho
    rows = [
        [
            d.get('name', ''),
            d.get('company', ''),
            d.get('title', ''),
            d.get('message', ''),
            d.get('profile_url', '')
        ]
        for d in dados
    ]

    body = {'values': rows}

    result = service.spreadsheets().values().append(
        spreadsheetId=spreadsheet_id,
        range=f'{sheet_name}!A1',
        valueInputOption='RAW',
        insertDataOption='INSERT_ROWS',
        body=body
    ).execute()

    print('✅ Dados adicionados à planilha com sucesso')

# %%
if __name__ == "__main__":
    curriculo = extrair_curriculo_gemini(CURRICULO_PATH)

    perfis_raw = extrair_perfis_linkedin(results)
    perfis = normalizar_perfis(perfis_raw)

    mensagens = []

    for perfil in perfis:
        mensagem = gerar_mensagem_template(
            nome=perfil["nome"],
            empresa=perfil["empresa"],
            cargo=perfil["cargo"],
            curriculo=curriculo
        )

        mensagens.append({
            "name": perfil["nome"],
            "company": perfil["empresa"],
            "title": perfil["cargo"],
            "message": mensagem,
            "profile_url": perfil["link"]
          })
# Out:
# Carregando currículo do arquivo salvo.
#
# === Gerando mensagem para Chris Graziani ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Brad Fuellenbach ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Matt Tompkins ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Steven Sill ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Susanna Kwon ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Eliot Sanford ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Andrew Morlin ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Thi Nguyen ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Steven Jiang ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Jose Garcia ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Nathaniel Douglas ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Kayla Kraft ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Rachel Haigh ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Greg Mannix ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Aryansh Sharma ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Josh Edwards ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Lars Schmidt ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Desmond Meray ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Luke Raad ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Mohammad Ariz Haider ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Kurt Gray ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Devan Rivera ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Daniel A. ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Kristin Straube ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Hunter Mott ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Dmitriy Boynetskiy ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Jason Tumilty ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Eric Hudson ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Jeff Moore ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Nicole Reyes ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Christie (Tucker) Linebarger ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Kristen Myers ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Suresh Teegireddy ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Greg Buechler ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Travis H. ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Kim Mulhern ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Siva Kumar ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Navneet Joshi ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Siddhant S. ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Kirstin Jung ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Brandon Gonzales ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Jay Mansavage ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Daniel Arias ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Dennis Smith ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Akhil Talashi ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Will Womack ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Manoj Kumar ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Carlos Cruz ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Jan Tegze – Director of Talent Acquisition | We're Hiring! ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Taylor Rowe ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Brian Wynne ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Tom Irtis ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Trent Cotton ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para christina lucia ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Chance Nguyen ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Tariq R. ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Dalia Wotman ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Chandan Kumar ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Marvelous David ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Taryn Ross ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Marvelous David ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Chandan Kumar ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Md Kamil ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Rebecca Hoskins ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Stephen Merriman ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Amber Tarrant ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Rajesh kumar ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Chris Dirks ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Riteish Mishra ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Ghulam Mustafa khan ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Thomas Sinnott ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Kim Cabrera ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Lucas Becker ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Julius Cranley ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Kaniska Singh ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Rohit Mukherjee ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Joshua Hernandez ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Inês Leite ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Koon Leong Lai ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para TatSan Tan ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Inês Leite ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Koon Leong Lai ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Venkata Suraj G. ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para TatSan Tan ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para John Robinson ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Wan Sam-HW ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Ahmed Mohammed‏ ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Muhammed F.‏ ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para DURGESH GUPTA ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para DURGESH GUPTA ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Owen She-Yin 🔹 ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Hoseine Wu Yue Pak ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Tayyab Rohail ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Grace Elle ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Pradyumna Bhattarai ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Lisa Branley ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Quang B. ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para Jay Kreps ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...
#
# === Gerando mensagem para David Gramblicka ===
# Nome completo: Erick Augusto
# Skills: JavaScript, TypeScript, C, Python, Java, React.js, Next.js, React Native, TailwindCSS, Vite, Expo, L...

# %%
    for perfil in perfis:
        print(perfil)
# Out:
# {'nome': 'Chris Graziani', 'cargo': 'Senior Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/christophergraziani'}
# {'nome': 'Brad Fuellenbach', 'cargo': 'Technical Recruiter', 'empresa': 'Apple', 'link': 'https://www.linkedin.com/in/fuellenbach'}
# {'nome': 'Matt Tompkins', 'cargo': 'Fullstack Engineering with TypeScript, ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/matt-tompkins-06271539'}
# {'nome': 'Steven Sill', 'cargo': 'Principal Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/stevesill'}
# {'nome': 'Susanna Kwon', 'cargo': 'Senior Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/susannato'}
# {'nome': 'Eliot Sanford', 'cargo': '🐙 Front-End Software Engineer ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/techieeliot'}
# {'nome': 'Andrew Morlin', 'cargo': 'Sr Technical Recruiter - Product and AI/ML', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/andrewmorlin'}
# {'nome': 'Thi Nguyen', 'cargo': 'Technical Talent Acquisition', 'empresa': 'Apple', 'link': 'https://www.linkedin.com/in/thinguyen1'}
# {'nome': 'Steven Jiang', 'cargo': 'Talent Acquisition Made Easy', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/stevenhireez'}
# {'nome': 'Jose Garcia', 'cargo': 'Senior Technical Recruiter @ Upstart', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/joeandresgarcia'}
# {'nome': 'Nathaniel Douglas', 'cargo': 'Technical Recruiter', 'empresa': 'Rippling', 'link': 'https://www.linkedin.com/in/nathaniel-douglas-53683618'}
# {'nome': 'Kayla Kraft', 'cargo': 'Talent Acquisition', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/kaylakraft'}
# {'nome': 'Rachel Haigh', 'cargo': 'Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/rachelhaigh'}
# {'nome': 'Greg Mannix', 'cargo': 'Technical Recruiting', 'empresa': 'Jane Street', 'link': 'https://www.linkedin.com/in/greg-mannix-52b5207'}
# {'nome': 'Aryansh Sharma', 'cargo': 'Software Engineer | React.js | Next.js', 'empresa': 'the company', 'link': 'https://in.linkedin.com/in/aryansh-sharma-91a452129'}
# {'nome': 'Josh Edwards', 'cargo': 'Technical Recruiter - Data Analytics & ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/jedwards45'}
# {'nome': 'Lars Schmidt', 'cargo': 'Talent Acquisition Partner @ Raytheon', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/larsusd'}
# {'nome': 'Desmond Meray', 'cargo': 'Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/desmond-meray-126770a'}
# {'nome': 'Luke Raad', 'cargo': 'Technical Recruiter Hiring Senior Engineers ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/lukeraad'}
# {'nome': 'Mohammad Ariz Haider', 'cargo': 'Software Engineer', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/mhaider93'}
# {'nome': 'Kurt Gray', 'cargo': 'Full Stack Software Engineer - JavaScript | React', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/kurtmgray'}
# {'nome': 'Devan Rivera', 'cargo': 'Software Engineer - React | JavaScript', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/devanrivera'}
# {'nome': 'Daniel A.', 'cargo': 'Frontend Developer | React JS | Next JS', 'empresa': 'the company', 'link': 'https://ng.linkedin.com/in/olamilekan-akinbo'}
# {'nome': 'Kristin Straube', 'cargo': 'Early in Profession Recruiting Lead', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/kristinstraube'}
# {'nome': 'Hunter Mott', 'cargo': 'Software Engineer turned Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/huntermott'}
# {'nome': 'Dmitriy Boynetskiy', 'cargo': 'Technical Recruiter @ TEKsystems', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/dmitriy-boynetskiy'}
# {'nome': 'Jason Tumilty', 'cargo': 'Global Talent Acquisition Leader', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/jasontumilty'}
# {'nome': 'Eric Hudson', 'cargo': 'Director, Talent Acquisition', 'empresa': 'Nutanix', 'link': 'https://www.linkedin.com/in/eric-hudson-82b66a20'}
# {'nome': 'Jeff Moore', 'cargo': 'VP of Talent Acquisition, Operations and ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/jeffmoore'}
# {'nome': 'Nicole Reyes', 'cargo': 'Sr. Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/nsreyestechrecruiter'}
# {'nome': 'Christie (Tucker) Linebarger', 'cargo': 'Talent Acquisition Leader & ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/christielinebarger'}
# {'nome': 'Kristen Myers', 'cargo': 'Senior Recruiter (Talent Acquisition)', 'empresa': 'CDW', 'link': 'https://www.linkedin.com/in/kristen-myers-0459913'}
# {'nome': 'Suresh Teegireddy', 'cargo': 'Talent Acquisition Leader', 'empresa': 'the company', 'link': 'https://in.linkedin.com/in/sureshteegireddy'}
# {'nome': 'Greg Buechler', 'cargo': 'Fractional Head of Talent Acquisition', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/gbuechler'}
# {'nome': 'Travis H.', 'cargo': 'Senior Technical Recruiter | Connecting Top ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/travishoosong'}
# {'nome': 'Kim Mulhern', 'cargo': 'Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/kim-mulhern-90b586140'}
# {'nome': 'Siva Kumar', 'cargo': 'Lead Technical Recruiter @ ResolveTech ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/siva-kumar-3ab319b0'}
# {'nome': 'Navneet Joshi', 'cargo': 'Experienced Software Engineer', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/navneetjoshi7'}
# {'nome': 'Siddhant S.', 'cargo': 'Software Engineer', 'empresa': 'Meta', 'link': 'https://www.linkedin.com/in/siddhanttsharma'}
# {'nome': 'Kirstin Jung', 'cargo': 'Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/kirstin-jung'}
# {'nome': 'Brandon Gonzales', 'cargo': 'Sr. Technical Recruiter @ Apple \uf8ff', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/brandongonzales'}
# {'nome': 'Jay Mansavage', 'cargo': 'Global Talent Acquisition Leader', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/jaymansavage'}
# {'nome': 'Daniel Arias', 'cargo': 'Technical Recruiter @Tesla', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/daniel-arias-029637180'}
# {'nome': 'Dennis Smith', 'cargo': 'Regional Head, Talent Acquisition Delivery', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/smith-dennis'}
# {'nome': 'Akhil Talashi', 'cargo': 'Software Engineer | Full-Stack Developer', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/akhil-talashi'}
# {'nome': 'Will Womack', 'cargo': 'Head of Talent Acquisition @ Korn Ferry', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/willwomack3'}
# {'nome': 'Manoj Kumar', 'cargo': 'Talent Acquisition Expert | Direct Client Hiring', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/manoj-kumar-a4753a44'}
# {'nome': 'Carlos Cruz', 'cargo': 'Senior Manager @ JSX | Talent Acquisition', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/carlos-cruz-0677a96'}
# {'nome': "Jan Tegze – Director of Talent Acquisition | We're Hiring!", 'cargo': 'Professional', 'empresa': 'the company', 'link': 'https://cz.linkedin.com/in/jantegze'}
# {'nome': 'Taylor Rowe', 'cargo': 'Talent Acquisition Specialist II', 'empresa': 'Ansys, part ...', 'link': 'https://www.linkedin.com/in/taylorjrowe'}
# {'nome': 'Brian Wynne', 'cargo': '| Talent Acquisition Leader', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/b-wynne'}
# {'nome': 'Tom Irtis', 'cargo': 'Sr. Technical Recruiter', 'empresa': 'JSR Tech', 'link': 'https://www.linkedin.com/in/tomirtis'}
# {'nome': 'Trent Cotton', 'cargo': 'Head of Talent Acquisition Insights & Analyst ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/trentcotton'}
# {'nome': 'christina lucia', 'cargo': 'Software Engineer', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/christina-lucia-34bb04224'}
# {'nome': 'Chance Nguyen', 'cargo': 'Software Engineer', 'empresa': 'Atlassian', 'link': 'https://www.linkedin.com/in/chanceknguyen'}
# {'nome': 'Tariq R.', 'cargo': 'Software Engineer', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/tariqarahman'}
# {'nome': 'Dalia Wotman', 'cargo': 'Talent Acquisition Leader', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/dkhattab'}
# {'nome': 'Chandan Kumar', 'cargo': 'Sr. Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/chandan-kumar-2a6449143'}
# {'nome': 'Marvelous David', 'cargo': 'Senior Software Developer -JavaScript', 'empresa': 'the company', 'link': 'https://ng.linkedin.com/in/david-marvelous'}
# {'nome': 'Taryn Ross', 'cargo': 'Connecting Talent with Tech Startups', 'empresa': 'the company', 'link': 'https://ca.linkedin.com/in/tarynross886'}
# {'nome': 'Marvelous David', 'cargo': 'Senior Software Developer -JavaScript', 'empresa': 'the company', 'link': 'https://ng.linkedin.com/in/david-marvelous'}
# {'nome': 'Chandan Kumar', 'cargo': 'Sr. Technical Recruiter', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/chandan-kumar-2a6449143'}
# {'nome': 'Md Kamil', 'cargo': '🧑\u200d💻SDE | React.js | JavaScript | Next.js | Angular', 'empresa': 'the company', 'link': 'https://in.linkedin.com/in/mdkamilit61?trk=public_profile_samename-profile'}
# {'nome': 'Rebecca Hoskins', 'cargo': 'Talent Acquisition Manager', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/rebecca-hoskins-7b846938'}
# {'nome': 'Stephen Merriman', 'cargo': 'Team Lead & Principal Technical ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/stevemerriman'}
# {'nome': 'Amber Tarrant', 'cargo': 'Talent Acquisition Leader @ Wise', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/amber-tarrant'}
# {'nome': 'Rajesh kumar', 'cargo': 'Senior IT Recruiter Senior Talent Acquisition', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/rajesh-kumar-874b80114'}
# {'nome': 'Chris Dirks', 'cargo': 'Fullstack Software Engineer', 'empresa': 'the company', 'link': 'https://ca.linkedin.com/in/chris-dirks'}
# {'nome': 'Riteish Mishra', 'cargo': 'Talent Acquisition Leader', 'empresa': 'the company', 'link': 'https://in.linkedin.com/in/riteish-mishra-14963719'}
# {'nome': 'Ghulam Mustafa khan', 'cargo': 'Software Engineer (.NET, React.js ...', 'empresa': 'the company', 'link': 'https://pk.linkedin.com/in/ghulam-mustufa-khan'}
# {'nome': 'Thomas Sinnott', 'cargo': 'Software Engineer', 'empresa': 'GTECH Printing', 'link': 'https://www.linkedin.com/in/tomsinnott'}
# {'nome': 'Kim Cabrera', 'cargo': 'Talent Acquisition Specialist', 'empresa': 'ZigZag Offshoring', 'link': 'https://ph.linkedin.com/in/kim-cabrera-067a96179'}
# {'nome': 'Lucas Becker', 'cargo': 'Mid Level Frontend Software Engineer', 'empresa': 'the company', 'link': 'https://br.linkedin.com/in/lucas-becker-software-engineer/en'}
# {'nome': 'Julius Cranley', 'cargo': 'Software Engineer', 'empresa': 'Bank of America', 'link': 'https://www.linkedin.com/in/julius-cranley-66b5b1398'}
# {'nome': 'Kaniska Singh', 'cargo': 'Global Talent Acquisition Team', 'empresa': 'Evalueserve', 'link': 'https://in.linkedin.com/in/kaniska-singh-b0753411b'}
# {'nome': 'Rohit Mukherjee', 'cargo': 'Leadership Hiring in Sales, IT ...', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/technical-staffing/'}
# {'nome': 'Joshua Hernandez', 'cargo': 'BS in Software Engineering', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/jhernandezluc'}
# {'nome': 'Inês Leite', 'cargo': 'IAM Software Engineer | Kuehne+Nagel', 'empresa': 'the company', 'link': 'https://pt.linkedin.com/in/ines-leite/en'}
# {'nome': 'Koon Leong Lai', 'cargo': 'Software Engineer', 'empresa': 'the company', 'link': 'https://my.linkedin.com/in/koon-leong-lai-76b773168'}
# {'nome': 'TatSan Tan', 'cargo': 'Software Engineer', 'empresa': 'Willowglen MSC Berhad', 'link': 'https://my.linkedin.com/in/tatsan-tan-b11091117'}
# {'nome': 'Inês Leite', 'cargo': 'IAM Software Engineer | Kuehne+Nagel', 'empresa': 'the company', 'link': 'https://pt.linkedin.com/in/ines-leite/en'}
# {'nome': 'Koon Leong Lai', 'cargo': 'Software Engineer', 'empresa': 'the company', 'link': 'https://my.linkedin.com/in/koon-leong-lai-76b773168'}
# {'nome': 'Venkata Suraj G.', 'cargo': 'Seasoned Software Engineer', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/g-suraj-v'}
# {'nome': 'TatSan Tan', 'cargo': 'Software Engineer', 'empresa': 'Willowglen MSC Berhad', 'link': 'https://my.linkedin.com/in/tatsan-tan-b11091117'}
# {'nome': 'John Robinson', 'cargo': 'Staff Software Engineer', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/john-robinson-a66357393'}
# {'nome': 'Wan Sam-HW', 'cargo': 'Software Engineer', 'empresa': '...', 'link': 'https://my.linkedin.com/in/wan-sam-hw-970129156'}
# {'nome': 'Ahmed Mohammed\u200f', 'cargo': '\u200fSoftware Engineer', 'empresa': 'the company', 'link': 'https://ae.linkedin.com/in/ahmed-mohammed-4a31b943'}
# {'nome': 'Muhammed F.\u200f', 'cargo': '\u200fSoftware Engineer | Dubai', 'empresa': 'the company', 'link': 'https://ae.linkedin.com/in/muhammedfathah'}
# {'nome': 'DURGESH GUPTA', 'cargo': 'Talent acquisition manager', 'empresa': 'Vibgyor ...', 'link': 'https://in.linkedin.com/in/durgesh-gupta-9ab46ab9'}
# {'nome': 'DURGESH GUPTA', 'cargo': 'Talent acquisition manager', 'empresa': 'Vibgyor ...', 'link': 'https://in.linkedin.com/in/durgesh-gupta-9ab46ab9'}
# {'nome': 'Owen She-Yin 🔹', 'cargo': 'Lead Software Engineer', 'empresa': 'Smartwyre 🔹Trial ...', 'link': 'https://uk.linkedin.com/in/owen-she-yin-%F0%9F%94%B9-30a93b14b'}
# {'nome': 'Hoseine Wu Yue Pak', 'cargo': 'Talent Acquisition Specialist', 'empresa': 'the company', 'link': 'https://ph.linkedin.com/in/hoseine-wu-yue-pak-84994698'}
# {'nome': 'Tayyab Rohail', 'cargo': 'Software engineer', 'empresa': 'the company', 'link': 'https://pk.linkedin.com/in/tayyab-rohail-04149926b'}
# {'nome': 'Grace Elle', 'cargo': 'Senior Software Engineer', 'empresa': 'the company', 'link': 'https://ng.linkedin.com/in/grace-elle-3134ba398'}
# {'nome': 'Pradyumna Bhattarai', 'cargo': 'Faculty | Associate Software Engineer', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/connectwithpradyumna'}
# {'nome': 'Lisa Branley', 'cargo': 'Talent Acquisition', 'empresa': 'Publicis Groupe', 'link': 'https://au.linkedin.com/in/lisa-branley-7ab9434b'}
# {'nome': 'Quang B.', 'cargo': 'Senior Software Engineer', 'empresa': 'the company', 'link': 'https://fr.linkedin.com/in/quang-b-749b5663?trk=people-guest_people_search-card'}
# {'nome': 'Jay Kreps', 'cargo': 'Co-founder and CEO', 'empresa': 'Confluent', 'link': 'https://www.linkedin.com/in/jaykreps'}
# {'nome': 'David Gramblicka', 'cargo': 'Strategic IT Leadership-as-a-Service', 'empresa': 'the company', 'link': 'https://www.linkedin.com/in/davidgramblicka'}

# %%
salvar_no_sheets(mensagens, SPREADSHEET_ID)
# Out:
# ✅ Dados adicionados à planilha com sucesso
